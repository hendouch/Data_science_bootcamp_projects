# %%
import os
import requests
from bs4 import BeautifulSoup
a ={'Ed_Sheeran':'https://www.lyrics.com/artist/Ed-Sheeran/2342870',
'Beyonce':'https://www.lyrics.com/artist/Beyonc%C3%A9/349078',
'SB19':'https://www.lyrics.com/artist/SB19/2137849178',
'Billie_Eilish':'https://www.lyrics.com/artist/Billie-Eilish/3177510',
'Ariana_Grande':'https://www.lyrics.com/artist/Ariana-Grande/1223462'}

# %%
artist=[]
song=[]
link=[]
for url in a:
    art_html = requests.get(a[url],'html.parser').text
    os.makedirs(url, exist_ok=True)
    file = open(file= "{}/{}.txt".format(url,url),mode="w")
    file.write(art_html)
    soup=BeautifulSoup(art_html)
    file.close()
    artist.append(soup.head.title.text)
    for links in soup.find_all(class_ = 'tal qx'):
       # print(links)
        link.append(links.find_all('li'))
            #song.append(subtag.text)
            #link.append(subtag.a['href'])

print(artist)
print(song)
print(link)
# Out:
# ['Ed Sheeran Lyrics, Songs and Albums | Lyrics.com', 'Beyoncé Lyrics, Songs and Albums | Lyrics.com', 'SB19 Lyrics, Songs and Albums | Lyrics.com', 'Billie Eilish Lyrics, Songs and Albums | Lyrics.com', 'Ariana Grande Lyrics, Songs and Albums | Lyrics.com']
# []
# ...

# %%
links = []
for link in titles_links_soup:
    links.append(link.a['href'])
links
