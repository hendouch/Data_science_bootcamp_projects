# %% [markdown]
# 1. read the small penguins file
# 2. Who is the 7th penguin?
# 3. How many Gentoos are in the dataset?
# 4. Who is the heaviest penguin
# 5. What is the mean size of female penguins?
# 6. How many penguins are heavier than 3kg?
# 7. Select 3 random penguins.

# %%
import pandas as pd

# %%
df = pd.read_csv("penguins_simple.csv", sep=";")

# %%
df
# Out:
#     Species  Culmen Length (mm)  Culmen Depth (mm)  Flipper Length (mm)  \
# 0    Adelie                39.1               18.7                181.0
# 1    Adelie                39.5               17.4                186.0
# 2    Adelie                40.3               18.0                195.0
# 3    Adelie                36.7               19.3                193.0
# 4    Adelie                39.3               20.6                190.0
# ..      ...                 ...                ...                  ...
# 328  Gentoo                47.2               13.7                214.0
# 329  Gentoo                46.8               14.3                215.0
# 330  Gentoo                50.4               15.7                222.0
# 331  Gentoo                45.2               14.8                212.0
# 332  Gentoo                49.9               16.1                213.0
#
#      Body Mass (g)     Sex
# 0           3750.0    MALE
# 1           3800.0  FEMALE
# ...

# %%
df.iloc[6]
# Out:
# Species                Adelie
# Culmen Length (mm)       39.2
# Culmen Depth (mm)        19.6
# Flipper Length (mm)     195.0
# Body Mass (g)          4675.0
# Sex                      MALE
# Name: 6, dtype: object

# %%
df[df["Species"]=="Gentoo"]["Species"].count()
# Out:
# 119

# %%
df["Species"].value_counts()
# Out:
# Adelie       146
# Gentoo       119
# Chinstrap     68
# Name: Species, dtype: int64

# %%
df[df["Body Mass (g)"] == df["Body Mass (g)"].max()]
# Out:
#     Species  Culmen Length (mm)  Culmen Depth (mm)  Flipper Length (mm)  \
# 231  Gentoo                49.2               15.2                221.0
#
#      Body Mass (g)   Sex
# 231         6300.0  MALE

# %%
df.sort_values(by="Body Mass (g)").tail(1)
# Out:
#     Species  Culmen Length (mm)  Culmen Depth (mm)  Flipper Length (mm)  \
# 231  Gentoo                49.2               15.2                221.0
#
#      Body Mass (g)   Sex
# 231         6300.0  MALE

# %%
df[df["Sex"] == "FEMALE"]["Body Mass (g)"].mean()
# Out:
# 3862.2727272727275

# %%
df.loc[df["Sex"] == "FEMALE"]["Body Mass (g)"].mean()
# Out:
# 3862.2727272727275

# %%
df.groupby("Sex")["Body Mass (g)"].mean()
# Out:
# Sex
# FEMALE    3862.272727
# MALE      4545.684524
# Name: Body Mass (g), dtype: float64

# %%
df[df["Body Mass (g)"] >= 3000].count()
# Out:
# Species                325
# Culmen Length (mm)     325
# Culmen Depth (mm)      325
# Flipper Length (mm)    325
# Body Mass (g)          325
# Sex                    325
# dtype: int64

# %%
df.sample(3)
# Out:
#     Species  Culmen Length (mm)  Culmen Depth (mm)  Flipper Length (mm)  \
# 325  Gentoo                46.2               14.1                217.0
# 102  Adelie                38.1               17.0                181.0
# 23   Adelie                37.9               18.6                172.0
#
#      Body Mass (g)     Sex
# 325         4375.0  FEMALE
# 102         3175.0  FEMALE
# 23          3150.0  FEMALE

# %% [markdown]
# ## Histogram

# %%
df["Body Mass (g)"].hist()
# Out:
# <AxesSubplot:>
